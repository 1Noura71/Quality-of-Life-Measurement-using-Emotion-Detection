# %%
from __future__ import print_function
import pandas as pd
import shutil
import os

# %%
labels = pd.read_csv(r'D:\dataset\MELD.Raw\train_emo.csv')

# %%
train_dir =r'D:\dataset\MELD.Raw\train_splits'
DR = r"D:\dataset\MELD.Raw\DR"
if not os.path.exists(DR):
    os.mkdir(DR)

# %%
for filename, class_name in labels.values:
    if not os.path.exists(DR + str(class_name)):
        os.mkdir(DR + str(class_name))
    src_path = train_dir + '/'+ filename +'.MP4' 
    dst_path = DR + str(class_name) + '/' + filename +'.MP4'
    try:
        shutil.copy(src_path, dst_path)
        print("sucessful")
    except IOError as e:
        print('Unable to copy file {} to {}'
              .format(src_path, dst_path))
    except:
        print('When try copy file {} to {}, unexpected error: {}'
              .format(src_path, dst_path, sys.exc_info()))
# Out:
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# ...
